# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
codes = pd.read_csv("DW3_set_exercise.csv")9
codes
# Out:
#        Unnamed: 0  Patient ID Diagnosis Code        Date
# 0               0   4725559.0          E03.9  2020-09-20
# 1               1   7637008.0          R53.1  2019-10-27
# 2               2   5068050.0          I48.1  2020-11-22
# 3               3   1342235.0          E11.9  2022-01-27
# 4               4   4520230.0          N39.0  2020-05-17
# ...           ...         ...            ...         ...
# 40601       40601   5728765.0          R53.0  2022-02-11
# 40602       40602   1806928.0          E03.9  2020-10-29
# 40603       40603    269579.0          J20.9  2021-02-10
# 40604       40604   4173184.0          M54.5  2019-12-12
# 40605       40605   1340228.0            E11  2020-07-25
#
# [40606 rows x 4 columns]

# %%
#1a
diabetes = []
for ind in codes.index:
    if codes['Diagnosis Code'][ind] in ('E08', 'E09', 'E10', 'E11', 'E13'):
        diabetes.append(codes['Patient ID'][ind])

diabetes_set = set(diabetes)
print(diabetes_set)
# Out:
# {1925120.0, 3842049.0, 1220613.0, 4956166.0, 1736711.0, 3465224.0, 7290887.0, 3432455.0, 4079623.0, 1376265.0, 3981318.0, 5611535.0, 3956753.0, 2465811.0, 4456467.0, 6127641.0, 1794074.0, 3956766.0, 7675935.0, 6365216.0, 3817505.0, 5685284.0, 7340071.0, 4751400.0, 6086697.0, 6742055.0, 6701106.0, 2048051.0, 5046324.0, 1982519.0, 3113015.0, 6938681.0, 3866682.0, 3637307.0, 2465852.0, 7618620.0, 4841530.0, 5161024.0, 6127682.0, 1302601.0, 6471754.0, 5390410.0, 3465290.0, 7192653.0, 7520334.0, 1097807.0, 4849744.0, 4767823.0, 4653138.0, 991310.0, 999501.0, 5890133.0, 6471767.0, 4210777.0, 1056858.0, 1425497.0, 4341852.0, 794719.0, 2334816.0, 540772.0, 6692966.0, 1564776.0, 7684202.0, 319597.0, 6635635.0, 2302070.0, 5079162.0, 499837.0, 6373505.0, 1851521.0, 7667843.0, 6226053.0, 5734535.0, 1654922.0, 7774349.0, 3481742.0, 5447823.0, 7200912.0, 4284562.0, 6267027.0, 3358868.0, 3063958.0, 663704.0, 1228953.0, 6619292.0, 5415071.0, 7725217.0, 3448993.0, 2662562.0, 4538532.0, 4661413.0, 237
# ...

# %%
#1b

print("Cardinality of diabetes set is: ", len(diabetes_set))
# Out:
# Cardinality of diabetes set is:  4902

# %%
#2a
covid = []
for ind in codes.index:
    if codes['Diagnosis Code'][ind] in ('U07.1', 'J12.82'):
        covid.append(codes['Patient ID'][ind])
covid_set = set(covid)
print(covid_set)
# Out:
# ...

# %%
#3b

print("Cardinality of Intersection set is: ", len(intersection_set))
# Out:
# Cardinality of Intersection set is:  165

# %%
#4a

covid_union = []
diabetes_union = []

for ind in codes.index:
    if codes['Diagnosis Code'][ind] in ('U07.1', 'J12.82'):
        covid_union.append(codes['Patient ID'][ind])
    if codes['Diagnosis Code'][ind] in ('E08', 'E09', 'E10', 'E11', 'E13'):
        diabetes_union.append(codes['Patient ID'][ind])
        
covid_union_set = set(covid_union)
diabetes_union_set = set(diabetes_union)
        
union_set = covid_union_set.union(diabetes_union_set)
print(union_set)
# Out:
# {3981318.0, 1736711.0, 7290887.0, 4079623.0, 1376265.0, 4456467.0, 6127641.0, 1769501.0, 3817505.0, 5685284.0, 7340071.0, 4751400.0, 6750250.0, 6701106.0, 2048051.0, 5046324.0, 2932790.0, 1982519.0, 3113015.0, 5914682.0, 3866682.0, 3637307.0, 7618620.0, 3768382.0, 5161024.0, 6127682.0, 2179145.0, 6471754.0, 6717515.0, 5390410.0, 7192653.0, 7520334.0, 1097807.0, 4849744.0, 4767823.0, 4653138.0, 4030547.0, 4472915.0, 7225429.0, 999501.0, 6471767.0, 4210777.0, 1425497.0, 6815836.0, 4341852.0, 458846.0, 7307359.0, 4587614.0, 5554274.0, 2998371.0, 540772.0, 7684202.0, 6635635.0, 1654900.0, 5079162.0, 1245312.0, 6373505.0, 5341314.0, 1851521.0, 7667843.0, 6226053.0, 5734535.0, 7667848.0, 1654922.0, 1622157.0, 3358868.0, 3063958.0, 1228953.0, 4505754.0, 6619292.0, 4341920.0, 1458336.0, 4538532.0, 6242476.0, 5980333.0, 3260588.0, 6013104.0, 2670769.0, 6422708.0, 6275253.0, 7012535.0, 6734010.0, 3342522.0, 196796.0, 1212606.0, 6881479.0, 5456071.0, 3162314.0, 4128970.0, 147663.0, 6750421.0, 5
# ...

# %%
print("Cardinality of Union set is: ", len(union_set))
# Out:
# Cardinality of Union set is:  6734

# %%
#5

from matplotlib_venn import venn2

venn2(subsets = (covid_set, diabetes_set), set_labels = ('COVID', 'Diabetes'))
plt.show()

# %%
#6a

filtered_codes = codes[codes['Diagnosis Code'].isin(['U07.1', 'J12.82', 'E08', 'E09', 'E10', 'E11', 'E13'])]

covid_dates = {}
diabetes_dates = {}
diabetes_after_covid = set()

for x in filtered_codes.index:
    patient_id = filtered_codes['Patient ID'][x]
    diagnosis_code = filtered_codes['Diagnosis Code'][x]
    date = filtered_codes['Date'][x]
    if diagnosis_code in ('E08', 'E09', 'E10', 'E11', 'E13'):
        diabetes_dates[patient_id] = date
    if diagnosis_code in ('U07.1', 'J12.82'):
        covid_dates[patient_id] = date

for patient_id, date_diabetes in diabetes_dates.items():
    if patient_id in covid_dates and date_diabetes > covid_dates[patient_id]:
        diabetes_after_covid.add(patient_id)  

diabetes_after_covid
# Out:
# {138575.0,
#  175474.0,
#  222248.0,
#  227866.0,
#  482256.0,
#  620623.0,
#  626112.0,
#  628441.0,
#  663704.0,
#  734644.0,
#  788972.0,
#  1165591.0,
#  1346682.0,
#  1441531.0,
#  1603639.0,
#  1610879.0,
#  1781822.0,
#  1811725.0,
#  1856152.0,
#  2299370.0,
#  2301586.0,
#  2320798.0,
#  2356742.0,
#  2369658.0,
#  2465811.0,
#  2481330.0,
#  2483513.0,
#  2629565.0,
#  2646629.0,
#  2986113.0,
#  3091854.0,
#  3428304.0,
#  3459970.0,
#  3636206.0,
#  3651321.0,
#  4056916.0,
#  4322839.0,
#  4406239.0,
#  4595704.0,
#  4852233.0,
#  4859240.0,
#  4908235.0,
#  4927942.0,
#  5019777.0,
#  5055782.0,
#  5159103.0,
#  5316149.0,
#  5588458.0,
#  5595625.0,
#  5637379.0,
#  5744768.0,
#  5855408.0,
#  5878004.0,
#  5931449.0,
#  6028000.0,
#  6029907.0,
#  6142172.0,
#  6399983.0,
#  6450265.0,
#  6471767.0,
#  6523303.0,
#  6615827.0,
#  7181285.0,
#  7231631.0,
#  7373904.0,
#  7542154.0,
#  7588327.0,
#  7609020.0,
#  7631360.0,
#  7635276.0}

# %%
#6b

print("Cardinality of Diabetes after Covid set is: ", len(diabetes_after_covid))
# Out:
# Cardinality of Diabetes after Covid set is:  70

# %%
#6c

patient_ids = []
diagnosis_codes = []
dates = []

for x in filtered_codes.index:
    patient_id = filtered_codes['Patient ID'][x]
    diagnosis_code = filtered_codes['Diagnosis Code'][x]
    date = filtered_codes['Date'][x]
    if patient_id in diabetes_after_covid:  
        patient_ids.append(patient_id)
        diagnosis_codes.append(diagnosis_code)
        dates.append(date)

breakdown_df = pd.DataFrame({
    'Patient ID': patient_ids,
    'Diagnosis Code': diagnosis_codes,
    'Date': dates})


diabetes_codes_count = breakdown_df[breakdown_df['Diagnosis Code'].isin(['E08', 'E09', 'E10', 'E11', 'E13'])]
diabetes_code_counts_df = diabetes_codes_count.groupby('Diagnosis Code').size()

print("Count breakdown for each diabetes code occurring only after COVID:")
print(diabetes_code_counts_df)
# Out:
# Count breakdown for each diabetes code occurring only after COVID:
# Diagnosis Code
# E08    13
# E09     8
# E10    16
# E11    17
# E13    16
# dtype: int64
